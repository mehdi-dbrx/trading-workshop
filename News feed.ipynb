# %%
from pyspark.sql import Row

data = [
    Row(
        Title="Impact de la maintenance du parc nucléaire français",
        Source="RTE France Energy Report",
        Date="14 décembre 2024",
        Content=(
            "Le parc nucléaire français fonctionne actuellement à environ 70% de sa capacité totale en raison de calendriers de maintenance prolongés sur plusieurs réacteurs. "
            "EDF a confirmé que 12 réacteurs restent à l'arrêt pour des inspections de corrosion et des mises à niveau de sécurité, réduisant la production de base disponible de près de 15 GW. "
            "Le programme de maintenance, initialement prévu pour se terminer en novembre, a été prolongé jusqu'en janvier 2025. Les analystes du secteur avertissent que cette capacité réduite coïncide avec les périodes de forte demande hivernale, créant potentiellement des pénuries d'approvisionnement lors de vagues de froid. "
            "RTE, l'opérateur du réseau de transport français, a émis des alertes préliminaires concernant un équilibre tendu entre l'offre et la demande dans les semaines à venir."
        )
    ),
    Row(
        Title="EDF émet un avertissement sur l'approvisionnement hivernal",
        Source="European Power Markets Daily",
        Date="13 décembre 2024",
        Content=(
            "Le PDG d'EDF a publiquement averti de tensions potentielles sur l'approvisionnement électrique hivernal en France. "
            "Dans une déclaration au régulateur de l'énergie, EDF a souligné des préoccupations concernant la satisfaction de la demande de pointe si les températures chutent significativement en dessous des normes saisonnières. "
            "L'entreprise a demandé aux consommateurs industriels de se préparer à d'éventuels arrangements de délestage et a appelé à une augmentation des importations en provenance des pays voisins. "
            "Les analystes du marché notent que les prix de l'électricité française pour livraison en janvier ont bondi de 18% la semaine dernière, reflétant des inquiétudes croissantes sur l'approvisionnement. "
            "L'avertissement a déclenché des discussions sur la réactivation des capacités au charbon et l'accélération du retour des unités nucléaires actuellement en maintenance."
        )
    ),
    Row(
        Title="L'Allemagne réduit ses exportations de gaz naturel",
        Source="European Gas Hub Analysis",
        Date="12 décembre 2024",
        Content=(
            "L'Allemagne a considérablement réduit ses exportations de gaz naturel vers les pays voisins car elle privilégie les niveaux de stockage domestiques et la demande industrielle. "
            "Les opérateurs de pipelines allemands signalent une réduction de 35% des flux de gaz transfrontaliers vers la France, la Belgique et les Pays-Bas par rapport au mois dernier. "
            "La décision fait suite à des livraisons de GNL inférieures aux prévisions dans les terminaux allemands et à une consommation domestique accrue en raison de conditions météorologiques plus froides. "
            "Cette réduction des exportations de gaz allemandes est particulièrement impactante pour la France, qui dépend de la production à base de gaz pour compléter la production nucléaire pendant les périodes de maintenance. "
            "Les prix européens du gaz au hub TTF ont augmenté de 12% suite à cette annonce, les analystes prévoyant une pression à la hausse continue tout au long de la saison de chauffage hivernal."
        )
    ),
    Row(
        Title="Contraintes de capacité d'interconnexion européenne",
        Source="ENTSO-E Market Update",
        Date="11 décembre 2024",
        Content=(
            "La capacité de transport d'électricité transfrontalière entre la France et ses voisins fait face à des contraintes importantes en raison de travaux de maintenance et d'une forte demande à travers le continent. "
            "L'interconnexion France-Allemagne fonctionne à capacité réduite suite à des problèmes techniques, limitant la capacité de la France à importer de l'électricité pendant les périodes de pointe. "
            "L'Espagne a également réduit les flux vers le nord en raison de pressions sur la demande domestique. "
            "Ces limitations d'interconnexion aggravent les défis de disponibilité nucléaire de la France, réduisant la capacité traditionnelle du pays à équilibrer l'approvisionnement par les importations. "
            "Les opérateurs de réseau coordonnent étroitement leurs actions pour maximiser la capacité de transport disponible, mais la variabilité de la production renouvelable dépendante des conditions météorologiques ajoute de la complexité aux opérations d'équilibrage en temps réel."
        )
    ),
    Row(
        Title="Prévisions météo hivernales - Front froid attendu",
        Source="Météo France Energy Briefing",
        Date="10 décembre 2024",
        Content=(
            "Les modèles météorologiques à long terme indiquent un front froid significatif se déplaçant à travers l'Europe du Nord à la mi-fin décembre, avec des températures attendues 5-8°C en dessous des moyennes saisonnières. "
            "La France pourrait connaître des températures négatives soutenues dans les principaux centres de population, poussant la demande d'électricité de pointe vers des sommets hivernaux. "
            "Les prévisions de production éolienne montrent une production inférieure à la moyenne pendant cette période en raison de systèmes de haute pression, resserrant davantage l'équilibre offre-demande. "
            "Les acteurs du marché de l'énergie surveillent de près les prévisions, car des conditions similaires lors des hivers précédents ont déclenché des flambées de prix et des activations d'urgence de la réponse à la demande. "
            "La combinaison de temps froid, de capacité nucléaire réduite et d'options d'importation limitées présente un scénario difficile pour les marchés de l'électricité français."
        )
    ),
    Row(
        Title="Les niveaux de stockage de gaz de l'UE diminuent plus rapidement que prévu",
        Source="Gas Infrastructure Europe Report",
        Date="9 décembre 2024",
        Content=(
            "Les installations de stockage de gaz naturel européennes se vident plus rapidement que les moyennes historiques pour cette période de l'année. "
            "Les niveaux de stockage à l'échelle de l'UE sont tombés à 78% de capacité, contre 85% au même moment l'hiver dernier. "
            "Les taux de retrait accélérés sont attribués à une production d'électricité à base de gaz supérieure à la normale compensant une production nucléaire et renouvelable réduite. "
            "La France a retiré 8% de son stockage au cours des deux dernières semaines seulement, soulevant des inquiétudes concernant les réserves disponibles si l'hiver s'étend plus longtemps que d'habitude. "
            "Les experts en sécurité énergétique soulignent l'importance de gérer les taux de retrait pour garantir des approvisionnements suffisants en cas de pics de demande en fin d'hiver."
        )
    ),
    Row(
        Title="La volatilité des prix spot de l'électricité augmente",
        Source="EPEX SPOT Market Analysis",
        Date="8 décembre 2024",
        Content=(
            "Les prix de l'électricité day-ahead en France ont affiché une volatilité sans précédent, avec des prix horaires allant de 95 €/MWh à 385 €/MWh au cours de journées de trading uniques. "
            "Cette variance de prix extrême reflète l'équilibre tendu entre l'offre et la demande et la flexibilité limitée du mix de production. "
            "Les heures de pointe en soirée voient systématiquement les prix les plus élevés car la production solaire diminue et la demande reste élevée. "
            "Les salles de marché signalent une activité de couverture accrue alors que les participants cherchent à gérer leur exposition à ces marchés spot volatils. "
            "Les fluctuations de prix créent à la fois du risque et des opportunités pour les acteurs de marché sophistiqués qui peuvent prévoir avec précision la dynamique offre-demande à court terme."
        )
    ),
    Row(
        Title="Bundesnetzagentur impose de nouvelles règles de transparence pour le trading de gaz",
        Source="German Energy Regulatory Authority",
        Date="15 décembre 2024",
        Content=(
            "L'agence fédérale des réseaux allemande, Bundesnetzagentur, a annoncé la mise en œuvre immédiate d'exigences de transparence renforcées pour les activités de trading de gaz naturel. "
            "Tous les acteurs du marché doivent désormais déclarer leurs positions de trading intrajournalières et les données d'utilisation du stockage dans les 2 heures suivant l'exécution, un délai nettement plus serré que la fenêtre de 24 heures précédente. "
            "Le régulateur a cité des préoccupations concernant la manipulation du marché pendant les périodes de contrainte d'approvisionnement pour justifier les nouvelles règles. "
            "De plus, le système d'allocation de capacité TCG (Trans Europa Naturgas Pipeline) fera face à des restrictions temporaires jusqu'en février 2025 pendant la réalisation de mises à niveau d'infrastructure, réduisant la capacité de pipeline disponible d'environ 20%. "
            "Les salles de marché à travers l'Europe s'empressent de mettre à jour leurs systèmes de reporting et d'ajuster leurs stratégies de couverture pour tenir compte de la flexibilité réduite des pipelines allemands."
        )
    )
]

df = spark.createDataFrame(data)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create a temporary view to use SQL AI functions
df.createOrReplaceTempView("news_articles")

# Apply ai_summarize function to each Content cell
df_with_summary = spark.sql("""
  SELECT 
    Title,
    Source,
    Date,
    Content,
    ai_summarize(Content, 50) AS Summary
  FROM news_articles
""")

display(df_with_summary)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
